# %%
import time    # for the right time interval for displaying
import psutil  # for getting the current CPU data
import matplotlib.pyplot as plt # for plotting graph

# %%
# To get the visualizations in the notebook, we have to do certain configurations
# %matplotlib notebook
plt.rcParams['animation.html'] = 'jshtml'

# %%
fig = plt.figure()  # create a variable holding the figure configuration (using matplot lib)
ax = fig.add_subplot(111) # adding sub-plot
fig.show # for displaying the figure
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">
# <bound method Figure.show of <Figure size 640x480 with 1 Axes>>

# %%
i = 0 # using iterator
x,y = [],[] #creating two empty list for putting values

while True: # creating an infinite loop
    x.append(i) # adding the iterated value to  list - x
    y.append(psutil.cpu_percent()) # adding the live cpu use percentage to list - y
    
    ax.plot(x,y, color='b') # plotting the graph using the sub-plot and giving it color as blue
    
    fig.canvas.draw() # instruction to draw the canvas for the variable - fig
    
    ax.set_xlim(left=max(0,i-50), right=i+50) # setting limit to the graph so that it doesnt contracts
    
    time.sleep(0.1) # interval of time before running the command to get the live cpu usage percentage
    i += 1 # iterating after every loop of instructions
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-7f62e53b1442> in <module>
#       8     ax.plot(x,y, color='b') # plotting the graph using the sub-plot and giving it color as blue
#       9
# ---> 10     fig.canvas.draw() # instruction to draw the canvas for the variable - fig
#      11
#      12     ax.set_xlim(left=max(0,i-50), right=i+50) # setting limit to the graph so that it doesnt contracts
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_webagg_core.py in draw(self)
#     151             super().draw()
#     152         finally:
# --> 153             self.manager.refresh_all()  # Swap the frames.
#     154
#     155     def draw_idle(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_webagg_core.py in refresh_all(self)
#     444             if diff is not None:
#     445                 for s in self.web_sockets:
# --> 446                     s.send_binary(diff)
#     447
#     448     @classmethod
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_nbagg.py in send_binary(self, blob)
#     204         data = b64encode(blob).decode('ascii')
#     205         data_uri = "data:image/png;base64,{0}".format(data)
# --> 206         self.comm.send({'data': data_uri})
#     207
#     208     def on_message(self, message):
#
# ~\anaconda3\lib\site-packages\ipykernel\comm\comm.py in send(self, data, metadata, buffers)
#     121         """Send a message to the frontend-side version of this comm"""
#     122         self._publish_msg('comm_msg',
# --> 123             data=data, metadata=metadata, buffers=buffers,
#     124         )
#     125
#
# ~\anaconda3\lib\site-packages\ipykernel\comm\comm.py in _publish_msg(self, msg_type, data, metadata, buffers, **keys)
#      69             parent=self.kernel._parent_header,
#      70             ident=self.topic,
# ---> 71             buffers=buffers,
#      72         )
#      73
#
# ~\anaconda3\lib\site-packages\jupyter_client\session.py in send(self, stream, msg_or_type, content, parent, ident, buffers, track, header, metadata)
#     735         if self.adapt_version:
#     736             msg = adapt(msg, self.adapt_version)
# --> 737         to_send = self.serialize(msg, ident)
#     738         to_send.extend(buffers)
#     739         longest = max([ len(s) for s in to_send ])
#
# ~\anaconda3\lib\site-packages\jupyter_client\session.py in serialize(self, msg, ident)
#     623             content = self.none
#     624         elif isinstance(content, dict):
# --> 625             content = self.pack(content)
#     626         elif isinstance(content, bytes):
#     627             # content is already packed, as in a relayed message
#
# ~\anaconda3\lib\site-packages\jupyter_client\session.py in <lambda>(obj)
#     101 # disallow nan, because it's not actually valid JSON
#     102 json_packer = lambda obj: jsonapi.dumps(obj, default=date_default,
# --> 103     ensure_ascii=False, allow_nan=False,
#     104 )
#     105 json_unpacker = lambda s: jsonapi.loads(s)
#
# ~\anaconda3\lib\site-packages\zmq\utils\jsonapi.py in dumps(o, **kwargs)
#      38         kwargs['separators'] = (',', ':')
#      39
# ---> 40     s = jsonmod.dumps(o, **kwargs)
#      41
#      42     if isinstance(s, unicode):
#
# ~\anaconda3\lib\json\__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# ~\anaconda3\lib\json\encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# KeyboardInterrupt:
